# %% [markdown]
# Choose 20 companies for analysis

# %%
companies = [
    "AAPL", "MSFT", "AMZN", "GOOGL", "TSLA",
    "META", "BRK.B", "JNJ", "JPM", "V",
    "PG", "NVDA", "HD", "DIS", "MA",
    "PYPL", "INTC", "NFLX", "KO", "PEP"
]

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.40)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.0.3)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.25.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.9.4)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2023.4)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (2024.6.2)

# %% [markdown]
# Using yahoo finance to create a function for fetching the latest news of a company

# %%
import yfinance as yf
def get_news(symbol):
    stock = yf.Ticker(symbol)
    news = stock.news
    return news

# %%
get_news("AAPL")[0]['title']
# Out:
# "Apple, Microsoft, or Nvidia: Which Will Be the World's Most Valuable Company a Year From Now?"

# %% [markdown]
# Clean the text by removing punctuations and making all lowercase

# %%
import string
def clean_text(headline):
  headline=headline.lower()
  headline = headline.translate(str.maketrans('', '', string.punctuation))
  return headline

# %% [markdown]
# Store all the news in a list, create a dictionary with the key as company name and the value as news

# %%
news_dataset = {company: get_news(company) for company in companies}
news_dataset={}
for i in companies:
  for j in range(len(get_news(i))):
    news=clean_text(get_news(i)[j]['title'])
    if news_dataset.get(i)==None:
      news_dataset[i]=[news]
    else:
      news_dataset[i].append(news)

# %%
news_dataset
# Out:
# {'AAPL': ['apple microsoft or nvidia which will be the worlds most valuable company a year from now',
#   'baby boomers and millennials face an intimidating task as stocks trade near record highs morning brief',
#   'renters are struggling more than homeowners in america’s tough housing market report says',
#   'why im thinking about selling some of my apple stock',
#   'best stock to buy right now apple vs amazon',
#   'apple and meta have discussed ai partnership wsj reports',
#   'nvidia and microsoft will make up over 40 of this popular etf heres why this alternative etf could be a better option',
#   'apple meta have discussed an ai partnership'],
#  'MSFT': ['apple microsoft or nvidia which will be the worlds most valuable company a year from now',
#   'do microsofts nasdaqmsft earnings warrant your attention',
#   'baby boomers and millennials face an intimidating task as stocks trade near record highs morning brief',
#   'missed out on nvidia heres 1 spectacular etf to buy instead',
#   '2 top tech stocks that could make you a millionaire',
#   '1 artificial intelligence ai stock down 67 that could get slashed in half again',
#   'nvidia and microsoft will make up over 40 of this popular etf heres why this alternative etf could be a better option',
#   'warren buffett doesnt own nvidia heres how hes profited from the artificial intelligence ai stocks big gains anyway'],
#  'AMZN': ['up 45 to 226 are these 3 stocks too hot to buy now',
#   'amazon is a top pick wedbush analyst on digital advertising',
#   'amazon ‘botched government relations’',
#   'best stock to buy right now apple vs amazon',
#   '2 growth stocks to buy now and hold forever',
#   '2 nobrainer warren buffett stocks to buy right now',
#   'best stock to buy right now amazon vs disney',
#   'warren buffett doesnt own nvidia heres how hes profited from the artificial intelligence ai stocks big gains anyway'],
#  'GOOGL': ['warren buffett doesnt own nvidia heres how hes profited from the artificial intelligence ai stocks big gains anyway',
#   'will alphabet be worth more than nvidia by 2025',
#   'hedge funds are crazy about alphabet inc googl',
#   '2 winners and 2 losers from apples latest artificial intelligence ai announcement',
#   'sports has to feed into a streamers ecosystem kevin mayer',
#   'dont lose money to this sneaky airline customer support scam',
#   '2 artificial intelligence ai stocks id buy over nvidia right now',
#   'will soundhound ai be a trilliondollar stock by 2050'],
#  'TSLA': ['teslas autonomous strategy to be key to ev maker reaching 1 trillionplus valuation wedbush says',
#   'tesla robotaxi next after huge elon musk pay deal byd in buy zone as sales rev',
#   'is elon musk misunderstood or understood all too well',
#   'tesla stock nasdaqtsla 2 catalysts that indicate a turnaround',
#   'li auto stock nasdaqli what has gone wrong',
#   'yahoo video musk must now convince the courts on his tesla pay package',
#   'musk must now convince the courts on his tesla pay package',
#   'analysts reset tesla stock price target ahead of deliveries and musks master plan 4'],
#  'META': ['apple and meta have discussed ai partnership wsj reports',
#   'apple meta have discussed an ai partnership',
#   '2 nobrainer stocks to buy right now for less than 1000',
#   '3 artificial intelligence stocks to buy and hold for great longterm potential',
#   'dow jones futures nvidia skid raises questions 3 stocks near buy points fed inflation gauge ahead',
#   'hedge funds are crazy about meta platforms inc meta',
#   'sp 500 giants meta ge aerospace lead five stocks near buy points',
#   'can ai startups outrun dotcom bubble comparisons investors aren’t so sure'],
#  'BRK.B': ['test what you know about the economic résumés of biden and trump',
#   'group chants no dead babies as donald trump addresses abortion restrictions exceptions',
#   'irss free taxfiling tool why turbotax says its not worried',
#   'more than 43 of warren buffettled berkshire hathaways 390 billion portfolio is invested in only 1 stock',
#   'heres why we think brookfield reinsurance nysebnre is well worth watching',
#   'we wouldnt be too quick to buy medtronic plc nysemdt before it goes exdividend',
#   'is it too late to buy chubb stock',
#   'kenyas ruto ready for conversation with protesters'],
#  'JNJ': ['johnson  johnson nysejnj seems to use debt quite sensibly',
#   '3 highyield dividend stocks near their 52week lows to buy and hold',
#   '2 top stocks to buy now for years of passive income',
#   'sector update health care stocks edge up in afternoon trading',
#   'the 30stock secret ‘don’t fight papa dow’',
#   'top midday stories boeing close to buying back spirit aerosystems amazon plans to launch premium alexa lockheed sanctioned by china american express acquires tock from squarespace',
#   'jj jnj seeks expanded use of tremfya for crohns disease',
#   'update johnson  johnson completes acquisition of proteologix'],
#  'JPM': ['disney tiktok spotify  more yf at cannes lions 2024',
#   'cannes lions 2024 what marketers are saying',
#   'regulators find weakness in living wills from bofa citi goldman and jpm',
#   'fed faults living wills of bofa citi goldman and jpmorgan',
#   'jpmorgan chase turnbull reach tentative settlement in wrongful termination suit',
#   'regulators cite big banks including goldman sachs and jpmorgan over living wills',
#   'fed fdic ding four of the largest us banks unwinding plans',
#   'jpmorgan extrader agree to settle wrongful firing lawsuit'],
#  'V': ['is it too late to buy visa stock',
#   'hedge funds are crazy about visa inc v',
#   'the 30stock secret ‘don’t fight papa dow’',
#   'those who invested in visa nysev five years ago are up 67',
#   'market chatter mastercard visa pressed by china to lower foreign bank transaction fees',
#   'topgolf callaway brands partners with visa',
#   'investors heavily search visa inc v here is what you need to know',
#   'reversing a creditcard charge has never been easier—or more abused'],
#  'PG': ['the 30stock secret ‘don’t fight papa dow’',
#   'wall street bulls look optimistic about pg pg should you buy',
#   '3 warren buffett stocks to hold forever',
#   'procter  gamble pg gains but lags market what you should know',
#   'procter  gamble company the pg is attracting investor attention here is what you should know',
#   'they broke up in 1989 but now his exgirlfriend is inheriting his 1 million retirement account after nearly 40 years',
#   'dow 30000 buy these 3 stocks now for the coming dow crash',
#   'trump offers ceos a cut to corporate taxes bidens team touts his support for global alliances'],
#  'NVDA': ['up 45 to 226 are these 3 stocks too hot to buy now',
#   'apple microsoft or nvidia which will be the worlds most valuable company a year from now',
#   'baby boomers and millennials face an intimidating task as stocks trade near record highs morning brief',
#   'what to expect in the markets this week',
#   'nvidia to launch in middle east amid us curbs on ai exports to region ooredoo ceo says',
#   'missed out on nvidia heres 1 spectacular etf to buy instead',
#   '3 tiny space value stocks which one should you buy',
#   '2 top tech stocks that could make you a millionaire'],
#  'HD': ['home depot likely to see longterm benefits from srs distribution acquisition ubs says',
#   'the 30stock secret ‘don’t fight papa dow’',
#   'president capital upgrades home depot to buy from neutral adjusts pt to 400 from 370',
#   'hd vs low which home improvement player edges over the other',
#   'home depot closes acquisition of srs distribution for 1825bn',
#   'home depot hd buys srs distribution reaches 1 trillion tam',
#   'home depot completes acquisition of srs distribution for 183 billion',
#   'the home depot completes acquisition of srs distribution'],
#  'DIS': ['disney tiktok spotify  more yf at cannes lions 2024',
#   '3 nobrainer stocks to buy with 100 right now',
#   'best stock to buy right now amazon vs disney',
#   'if youd invested 1000 in disney stock 20 years ago heres how much youd have today',
#   'workers sue disney claiming they were fraudulently induced to move to florida from california',
#   'the 30stock secret ‘don’t fight papa dow’',
#   'happily paying a mouse’s ransom',
#   'why the market dipped but walt disney dis gained today'],
#  'MA': ['hedge funds are crazy about mastercard incorporated ma',
#   'mastercard stock nysema excellent growth points to new highs',
#   'mastercard insider sold shares worth 4072170 according to a recent sec filing',
#   'market chatter mastercard visa pressed by china to lower foreign bank transaction fees',
#   'q1 2024 16 increase in foreign tourists and a 7 increase in spending in turkey – mastercard',
#   'china asks visa mastercard to cut card fees bloomberg news reports',
#   'mastercard insider sold shares worth 2339199 according to a recent sec filing',
#   'blocks sq expanding partner base boosts bnpl offerings'],
#  'PYPL': ['can paypal double in 5 years heres what it would take',
#   'prediction these could be the bestperforming fintech stocks through 2030',
#   'could paypal stock double this year',
#   'could this undervalued stock make you a millionaire one day',
#   'why the market dipped but paypal pypl gained today',
#   'jim cramer weighs in on paypal\xa0holdings inc nasdaqpypl',
#   'sector update financial stocks edge higher prebell thursday',
#   'paypal appoints srini venkatesan as chief technology officer'],
#  'INTC': ['is intel corporations nasdaqintc stock price struggling as a result of its mixed financials',
#   'missed out on nvidia heres 1 spectacular etf to buy instead',
#   '3 reasons to buy nvidia stock before june 26',
#   'if youd invested 10000 in advanced micro devices stock 5 years ago heres how much youd have today',
#   'think nvidia stock is a bubble buy these 2 ai stocks instead',
#   'prediction artificial intelligence ai stock nvidia will struggle to retain its trilliondollar market cap by 2026',
#   'could investing 50000 in advanced micro devices make you a millionaire',
#   'why nvidias gravy train could come to screeching halt after a volatile trading week'],
#  'NFLX': ['2 magnificent growth stocks that have outperformed the nasdaq in 2024 and can keep soaring',
#   'how netflix is taking a page from disneys parks playbook',
#   'sports has to feed into a streamers ecosystem kevin mayer',
#   'netflix flirts with alltime highs as investors cheer ad momentum foray into live sports',
#   'paige butcher in alex perry lil nas x in oversize denim and more stars at the ‘beverly hills cop axel f’\xa0premiere',
#   'traditional british broadcasters growing faster than netflix as viewers switch from streaming',
#   'netflix bosses greg peters and ted sarandos bring the right combination of expertise',
#   'why netflix nflx is a top momentum stock for the longterm'],
#  'KO': ['want to beat the sp 500 youll regret buying this top warren buffett stock',
#   '2 nobrainer warren buffett stocks to buy right now',
#   'the 30stock secret ‘don’t fight papa dow’',
#   'the road to net zero – the emissions targets of the world’s drinks giants',
#   'can the cocacola companys nyseko roe continue to surpass the industry average',
#   'campaign trail cocacola spills soda to focus on moments of connection',
#   'cocacola and pepsi have more than tripled their dividends over the last 20 years can keurig dr pepper do the same',
#   'cocacola india launches 100 rpet bottle in assp format'],
#  'PEP': ['the road to net zero – big food’s emissions pledges',
#   'the road to net zero – the emissions targets of the world’s drinks giants',
#   'cocacola and pepsi have more than tripled their dividends over the last 20 years can keurig dr pepper do the same',
#   'pepsico inc pep is a trending stock facts to know before betting on it',
#   'pepsico releases 2023 esg summary highlighting pepsico positive pep results',
#   'q1 earnings outperformers pepsico nasdaqpep and the rest of the beverages and alcohol stocks',
#   'the nasdaq is soaring but these 3 stocks are near their 52week lows',
#   '4 reasons to buy celsius stock like theres no tomorrow']}

# %% [markdown]
# Sentiment Analysis using VADER

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
sia = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
def analyze_sentiment_nltk(news):
    sentiments = []
    for article in news:
        sentiment_score=sia.polarity_scores(article)['compound']
        sentiments.append(sentiment_score)
    if sentiments:
        avg_sentiment = sum(sentiments)/len(sentiments)
    else:
        avg_sentiment = 0
    return avg_sentiment

# %%
analyze_sentiment_nltk(news_dataset["AAPL"])
# Out:
# 0.12691249999999998

# %% [markdown]
# Sentiment Analysis using TextBlob

# %%
from textblob import TextBlob

# %%
def analyze_sentiment_textblob(news):
  sentiments = []
  for article in news:
    sentiment_score = TextBlob(article).sentiment.polarity
    sentiments.append(sentiment_score)
  if sentiments:
    avg_sentiment = sum(sentiments)/len(sentiments)
  else:
    avg_sentiment = 0
  return avg_sentiment

# %%
analyze_sentiment_textblob(news_dataset["AAPL"])
# Out:
# 0.2248015873015873

# %% [markdown]
# Gather the sentiment scores and make suggestions to buy or sell stock based on values of the scores

# %%
nltk_sentiment_scores = [analyze_sentiment_nltk(news_dataset[company]) for company in companies]
textblob_sentiment_scores = [analyze_sentiment_textblob(news_dataset[company]) for company in companies]
overall=[(nltk_sentiment_score+textblob_sentiment_score)/2 for nltk_sentiment_score,textblob_sentiment_score in zip(nltk_sentiment_scores,textblob_sentiment_scores)]
def sentiment_suggestion(score):
    if score > 0.05:
        return 'positive'
    elif score < -0.05:
        return 'negative'
    else:
        return 'neutral'
nltk_suggestions = [sentiment_suggestion(score) for score in nltk_sentiment_scores]
textblob_suggestions = [sentiment_suggestion(score) for score in textblob_sentiment_scores]
overall_suggestions=[sentiment_suggestion(score) for score in overall]

# %% [markdown]
# Display the final dataset along with the suggestions

# %%
df = pd.DataFrame()
df['Company']=companies
df['NLTK Sentiment Score']=nltk_sentiment_scores
df['NLTK Sentiment Suggestions']=nltk_suggestions
df['TextBlob Sentiment Score']=textblob_sentiment_scores
df['TextBlob Sentiment Suggestions']=textblob_suggestions
df['Overall Sentiment Suggestions']=overall_suggestions
df
# Out:
#    Company  NLTK Sentiment Score NLTK Sentiment Suggestions  \
# 0     AAPL              0.126912                   positive
# 1     MSFT              0.224612                   positive
# 2     AMZN              0.389800                   positive
# 3    GOOGL              0.168037                   positive
# 4     TSLA              0.022613                    neutral
# 5     META              0.114900                   positive
# 6    BRK.B              0.061187                   positive
# 7      JNJ              0.084288                   positive
# 8      JPM             -0.134337                   negative
# 9        V             -0.196763                   negative
# 10      PG             -0.057337                   negative
# 11    NVDA              0.041438                    neutral
# 12      HD              0.034737                    neutral
# 13     DIS              0.176487                   positive
# 14      MA              0.180912                   positive
# 15    PYPL              0.065837                   positive
# 16    INTC             -0.001900                    neutral
# 17    NFLX              0.218812                   positive
# 18      KO             -0.069962                   negative
# 19     PEP              0.042325                    neutral
#
#     TextBlob Sentiment Score TextBlob Sentiment Suggestions  \
# 0                   0.224802                       positive
# 1                   0.236574                       positive
# 2                   0.258929                       positive
# 3                  -0.057143                       negative
# 4                  -0.012500                        neutral
# 5                   0.028274                        neutral
# 6                   0.185417                       positive
# 7                   0.045833                        neutral
# 8                   0.062500                       positive
# 9                  -0.140625                       negative
# 10                 -0.033333                        neutral
# 11                  0.237500                       positive
# 12                 -0.057813                       negative
# 13                  0.253571                       positive
# 14                 -0.118561                       negative
# 15                  0.015625                        neutral
# 16                  0.087500                       positive
# 17                  0.302760                       positive
# 18                  0.050298                       positive
# 19                  0.061742                       positive
#
#    Overall Sentiment Suggestions
# 0                       positive
# 1                       positive
# 2                       positive
# 3                       positive
# 4                        neutral
# 5                       positive
# 6                       positive
# 7                       positive
# 8                        neutral
# 9                       negative
# 10                       neutral
# 11                      positive
# 12                       neutral
# 13                      positive
# 14                       neutral
# 15                       neutral
# 16                       neutral
# 17                      positive
# 18                       neutral
# 19                      positive
